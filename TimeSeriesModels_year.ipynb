# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from models import prepare_TS, estimate_for_n_clusters, get_silhouette_plot, prepare_whole_year

from sklearn.preprocessing import MinMaxScaler


from minisom import MiniSom
from tslearn.barycenters import dtw_barycenter_averaging
from tslearn.clustering import TimeSeriesKMeans, silhouette_score
from sklearn.cluster import KMeans

from sklearn.decomposition import PCA

from IPython.display import clear_output

# %% [markdown]
# ## 2019

# %%
get_silhouette_plot(year=2019, month=None, metric='euclidean')
# Out:
# ([2, 5, 7, 10, 13, 15, 17, 20, 25, 30, 35],
#  [0.38174473798936204,
#   0.3997337014824731,
#   0.3448055629176281,
#   0.2851986469872226,
#   0.26693663471230844,
#   0.21666732707396014,
#   0.2436047559952073,
#   0.21537953584431135,
#   0.22009224377338965,
#   0.19227894496090908,
#   0.19963086265301913])

# %%
estimate_for_n_clusters(2019, n_clusters=7, metric='euclidean')

# %% [markdown]
# Whole year: 2019
# Important months: January, July, April
# Week: July 15-21, January 28-Feb3, April 15-21
# Day:
#     work: January 30, July 10, 8 April
#     weekend: January 26, July 20, 7 April
