# %%
from gtdownloader import TweetDownloader

# %%
import gtdownloader as gtd

# %%
# create downloader using Twitter API credentials
gtd = TweetDownloader(
    name='test_dog', 
    credentials='data/credentials/twitter_keys.yaml',
    output_folder='data/TwitterDownloads')

# %%
gtd.get_tweets(
               query='((comed) OR (electricity) OR (outage)) (place: "chicago")',
               lang='en',
               start_time='01/01/2017',
               end_time='12/31/2022',
               max_tweets=2000000            
)
# Out:
# ...
# Current progress saved at: data/TwitterDownloads\temp_test_dog_03162023_163253.csv
# Ending page 1 with next_token=b26v89c19zqg8o3fpyzoczjzr8d655iafmd0wkgpnf1j1. 492 tweets retrieved (492 total)
# Current progress saved at: data/TwitterDownloads\temp_test_dog_03162023_163253.csv
# Ending page 2 with next_token=b26v89c19zqg8o3fpdp9lswbq7m05py29n4ygfdiro399. 494 tweets retrieved (986 total)
# Current progress saved at: data/TwitterDownloads\temp_test_dog_03162023_163253.csv
# Ending page 3 with next_token=b26v89c19zqg8o3fos8uwe3ubiwqd1ew44bxlj7gbkvp9. 487 tweets retrieved (1473 total)
# Current progress saved at: data/TwitterDownloads\temp_test_dog_03162023_163253.csv
# Ending page 4 with next_token=b26v89c19zqg8o3fo7gd3zcm4wburtb4hy5rw29502qgt. 485 tweets retrieved (1958 total)
# Current progress saved at: data/TwitterDownloads\temp_test_dog_03162023_163253.csv
# Ending page 5 with next_token=b26v89c19zqg8o3fnm2zuo8ilvrr8ypahbnbwsvv1vzwd. 488 tweets retrieved (2446 total)
# ...

# %%
# create downloader using Twitter API credentials
gtd = TweetDownloader(
    name='power_outage', 
    credentials='data/credentials/twitter_keys.yaml',
    output_folder='data/TwitterDownloads')

gtd.get_tweets(
               query='((power outage) OR (electricity outage) OR (outage) OR (energy outage) OR (comed outage)) (place: "chicago")',
               lang='en',
               start_time='01/01/2017',
               end_time='12/31/2022',
               max_tweets=2000000            
)
# Out:
# ...
# Current progress saved at: data/TwitterDownloads\temp_power_outage_03092023_180510.csv
# Ending page 1 with next_token=b26v89c19zqg8o3foswt3if7ufbzvzfzpvy59ymr14ry5. 409 tweets retrieved (409 total)
# Current progress saved at: data/TwitterDownloads\temp_power_outage_03092023_180510.csv
# Ending page 2 with next_token=b26v89c19zqg8o3fnlx157c78tt06ph8urnh90bpuc4n1. 403 tweets retrieved (812 total)
# Current progress saved at: data/TwitterDownloads\temp_power_outage_03092023_180510.csv
# Ending page 3 with next_token=1jzu9lk96gu5npw3j43gl73gp413xjz2f2jca459c2v1. 476 tweets retrieved (1288 total)
# Current progress saved at: data/TwitterDownloads\temp_power_outage_03092023_180510.csv
# Tweets download done. A total of 1314 tweets were retrieved.
# csv files data/TwitterDownloads\power_outage_tweets_03092023_180510.csv, data/TwitterDownloads\power_outage_places_03092023_180510.csv, and data/TwitterDownloads\power_outage_authors_03092023_180510.csv were generated

# %%
gtd.tweets_df[:20]
# Out:
#                                                  text      conversation_id  \
# 0   My electricity bill was 90 dollars I’ve been h...  1608974756535205889
# 1   Also, Chicago enjoys a nearly carbon-free grid...  1608798383917109253
# 2   It's sad enough that L.R. residence are left d...  1608679871227768832
# 3   Chicago Heights, IL (1:21 PM)\rGrid Power Outa...  1608546121625882625
# 4   This explains the @twitter outage reports. Loo...  1608423331195392002
# 5   Chicago, IL (10:34 PM)\rGrid Power Outage Even...  1607961013965537281
# 6   Chicago, IL (4:24 PM)\rGrid Power Outage Event...  1607866655169777664
# 7   Chicago, IL (11:31 AM)\rGrid Power Outage Even...  1607794924337991680
# 8   Chicago, IL (7:47 AM)\rGrid Power Outage Event...  1607738297136156673
# 9   Approaching 60 hours and no Wi-Fi, but seeing ...  1607565860851294208
# 10  All I wanna do is play catch with my son, but ...  1607517054969729025
# ...
