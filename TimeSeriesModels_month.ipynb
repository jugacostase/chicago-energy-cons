# %%
from plots import inertia_plot, get_silhouette_plot
from models import prepare_TS, estimate_knn_clusters,  prepare_whole_year, estimate_som_clusters

# %% [markdown]
# ## January

# %%
inertia_plot(year=2019, month=1, metric='euclidean')
# Out:
# 100.0%

# %%
estimate_knn_clusters(2019, 1, None, 7, metric='euclidean')

# %% [markdown]
# ## July

# %%
inertia_plot(year=2019, month=7, metric='euclidean')
# Out:
# 100.0%

# %%
estimate_knn_clusters(2019, 7, None, 5)

# %% [markdown]
# ## April

# %%
inertia_plot(year=2019, month=4, metric='euclidean')
# Out:
# 100.0%

# %%
estimate_knn_clusters(2019, 4, None, 5)

# %% [markdown]
# Whole year: 2019
# Important months: January, July, April
# Week: July 15-21, January 28-Feb3, April 15-21
# Day:
#     work: January 30, July 10, 8 April
#     weekend: January 26, July 20, 7 April
