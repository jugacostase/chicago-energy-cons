# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from models import prepare_TS, estimate_for_n_clusters, get_silhouette_plot

from sklearn.preprocessing import MinMaxScaler


from minisom import MiniSom
from tslearn.barycenters import dtw_barycenter_averaging
from tslearn.clustering import TimeSeriesKMeans, silhouette_score
from sklearn.cluster import KMeans

from sklearn.decomposition import PCA

from IPython.display import clear_output

# %% [markdown]
# ## January

# %%
get_silhouette_plot(year=2019, month=1)
# Out:
# Generating silhouette plot...
# 2
# 5
# 7
# 10
# 13
# 15
# 17
# 20
# 25

# %%
estimate_for_n_clusters(2019, 1, None, 13)

# %% [markdown]
# ## July

# %%
get_silhouette_plot(year=2019, month=7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_silhouette_plot(year=2019, month=7)
#
# NameError: name 'get_silhouette_plot' is not defined

# %%
estimate_for_n_clusters(2019, 7, None, 15)
# Out:
# Excluded the following zip codes [60958]

# %% [markdown]
# ## April

# %%
get_silhouette_plot(year=2019, month=4)
# Out:
# ([2, 5, 7, 10, 13, 15, 17, 20, 25, 30, 35],
#  [0.2666644340957557,
#   0.11654883603484921,
#   0.12500925734840332,
#   0.1021911237150053,
#   0.10384618156829391,
#   0.09390082938725525,
#   0.09094415712987275,
#   0.1054553518361894,
#   0.08348194596334667,
#   0.077791669470859,
#   0.07233032795043097])

# %%
estimate_for_n_clusters(2019, 4, None, 5)
# Out:
# Excluded the following zip codes [61091]

# %% [markdown]
# Whole year: 2019
# Important months: January, July, April
# Week: July 15-21, January 28-Feb3, April 15-21
# Day:
#     work: January 30, July 10, 8 April
#     weekend: January 26, July 20, 7 April
